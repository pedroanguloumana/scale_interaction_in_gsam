# %%
# %load_ext autoreload 
# %autoreload 2
import xarray as xr
from src.loading import *
import matplotlib.pyplot as plt
import xeofs as xe
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
w = load_coarse_gsam_w()

# %%
f = '/Users/pedro/scale_interaction_in_gsam/data/old_coarse_w/merged.nc'
old = xr.open_dataset(f)

# %%
model = xe.single.EOF(n_modes=10, center=True, standardize=False)
model.fit(old['W'] * old['rho'], ('lat', 'lon', 'time'))

# %%
model.components().sel(mode=1).plot(y='z', label='Mode 1')
model.components().sel(mode=2).plot(y='z', label='Mode 2')
plt.legend()
